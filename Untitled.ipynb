# %%
from subprocess import check_output

# %%
check_output("dir", shell=True)
# Out:
# ' Volume in drive C is Windows\r\n Volume Serial Number is 16D7-47EB\r\n\r\n Directory of C:\\Users\\povey_000\\Dropbox\\4th Year Project\\Presentation\r\n\r\n25/02/2016  16:15    <DIR>          .\r\n25/02/2016  16:15    <DIR>          ..\r\n25/02/2016  16:13    <DIR>          .ipynb_checkpoints\r\n25/02/2016  15:17           557,887 kepler_data_m=1.00E+10_e=0.0_incline=0.0_AC.csv\r\n15/02/2016  11:17         1,118,547 kepler_data_m=1.00E+10_e=0.0_incline=0.0_C.csv\r\n25/02/2016  15:50        15,534,806 PM_m=1.00E+10_e=0.0_incline=0.0_AC.mp4\r\n15/02/2016  11:33        23,422,535 PM_m=1.00E+10_e=0.0_incline=0.0_C.mp4\r\n25/02/2016  16:15             4,788 Untitled.ipynb\r\n               5 File(s)     40,638,563 bytes\r\n               3 Dir(s)  836,194,590,720 bytes free\r\n'

# %%
import os
x=os.system('dir')

# %%
print x
# Out:
# 0

# %%
os.system('ffmpeg -i kepler.mp4 -c:v libvpx -b:v 1M -c:a libvorbis kepler.webm')

# %%
from sympy import solve,Symbol

# %%
r=Symbol('r')
theta=Symbol('theta')
A=6.69048E-12
E=8.446739E-10

# %%
#solve([r>0,r<5.0E4,(E**2)*(r**6)-(A**2)*(4-(3*r/5.0E4))],r)

# %%
mp=10000*1.67262158E-27
M=1.0E21
ms=1.0E20
G=6.673E-11
vPar=1.0E7
vPerp=1.0E6
rIn=5.0E4
B_In=0.8
c1=1.0E-7
mu=(0.5*mp*vPerp*vPerp)/B_In
E=0.5*mp*(vPar**2)

# %%
#r=Symbol('r')
#solve(E*E*(r**6)-((mu*M*c1)**2)*(4-3*r/rIn),r)

# %%
solve(r,r)

# %%
from scipy import optimize
import numpy as np

# %%
def func(x):
    mp=10000*1.67262158E-27
    q=1.60217733E-19
    M=1.0E21
    ms=1.0E20
    G=6.673E-11
    vPar=1.0E7
    vPerp=1.0E6
    rIn=5.0E4
    B_In=0.8
    c1=1.0E-7
    mu=(0.5*mp*vPerp*vPerp)/B_In
    E=0.5*mp*(vPar**2+vPerp**2)
    Pphi=(q*M*c1/rIn)
    val1=((M*mu*c1)/(x[0]**3))*sqrt(3*(cos(x[1])**2)+1)-E;
    val2=(q*M*c1/x[0])*((sin(x[1]))**2)-Pphi;
    return [val1,val2];

# %%
sol1=optimize.root(func, [15112.3597233968,0.5])
sol2=optimize.root(func, [15112.3597233968,2.5])
print sol1.x, sol2.x
# Out:
# [  1.30450209e+04   5.36096620e-01] [  1.30450209e+04   2.60549603e+00]

# %%
eval1=func(sol.x)
eval2=func([15112.3597233968,0.583525260031071])
print eval1
print eval2
sol
# Out:
# [5.44801830942738e-22, -4.45436759859805e-22]
# [-3.12307289614476e-10, 1.39937631014270e-12]
#   status: 1
#  success: True
#      qtf: array([ -1.99547766e-18,   2.23780101e-18])
#     nfev: 11
#        r: array([  1.90607610e-13,   1.97639321e-10,  -1.14392125e-09])
#      fun: array([  5.44801831e-22,  -4.45436760e-22])
#        x: array([  1.30450209e+04,   5.36096620e-01])
#  message: 'The solution converged.'
#     fjac: array([[-0.98803382, -0.15423741],
#        [ 0.15423741, -0.98803382]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
r=np.linspace(0,5.0E4,1000)
F1,F2=func([r,r])
fig=plt.figure()
ax=plt.axes(xlim=(0.0,20000),ylim=(-1.0E6,1.0E6));
ax.plot(r,F)
plt.show()

# %%
plt.show()

# %%
func([15112.3597233968,0.583525260031071])
# Out:
# [-3.12307289614476e-14, 0]

# %%
from sympy.solvers.solvers import solve_linear
from sympy import Symbol, sqrt, cos, sin

# %%
E
# Out:
# 8.3631079e-10

# %%
def FLFunc(theta):
    mp=10000*1.67262158E-27
    q=1.60217733E-19
    M=1.0E21
    ms=1.0E20
    G=6.673E-11
    vPar=1.0E7
    vPerp=1.0E6
    rIn=5.0E4
    B_In=0.8
    c1=1.0E-7
    sAlphaS=(vPerp*vPerp)/(vPerp*vPerp+vPar*vPar)
    mu=(0.5*mp*vPerp*vPerp)/B_In
    E=0.5*mp*(vPar**2+vPerp**2)
    Pphi=(q*M*c1/rIn)
    return (np.sin(theta)**6)/np.sqrt(3*(np.cos(theta)**2)+1) - sAlphaS

# %%
optimize.fsolve(FLFunc,0.3,maxfev=2000000,full_output=True)
# Out:
# (array([ 0.53609662]),
#  {'fjac': array([[-1.]]),
#   'fvec': array([  6.93889390e-18]),
#   'nfev': 17,
#   'qtf': array([ -1.07867361e-12]),
#   'r': array([-0.10404118])},
#  1,
#  'The solution converged.')

# %%
FLFunc(0.53609662)
# Out:
# 4.9582029454375842e-11

# %%
vPerp/(vPerp*vPerp+vPar*vPar)
# Out:
# 9.900990099009902e-09

# %%
optimize.brentq(FLFunc,0.2,0.6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-025d8b3f4105> in <module>()
# ----> 1 optimize.brentq(FLFunc,0.2,0.6)
#
# C:\Python27\lib\site-packages\scipy\optimize\zeros.pyc in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     413     if rtol < _rtol:
#     414         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 415     r = _zeros._brentq(f,a,b,xtol,rtol,maxiter,args,full_output,disp)
#     416     return results_c(full_output, r)
#     417
#
# ValueError: f(a) and f(b) must have different signs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
theta=np.linspace(0.1,np.pi,200)

# %%
val=FLFunc(theta)

# %%
plt.plot(theta,val)
zero=[0]*200
plt.plot(theta,zero)

# %%
r=np.linspace(0,16000,1000)
theta1=sol1.x[1]*1000
theta2=sol2.x[1]*1000
ax = plt.subplot(111, projection='polar')
ax.set_theta_zero_location("N")
ax.plot(theta, r, color='r', linewidth=3)
ax.set_rmax(2.0)
ax.grid(True)

# %%
from matplotlib.ticker import FuncFormatter

# define how your plots look:


def degToRad(theta, pos):
    'The two args are the value and tick position'
    return '%1.1f $\pi$' % (theta/180)

formatter = FuncFormatter(degToRad)
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes
import mpl_toolkits.axisartist.angle_helper as angle_helper
from matplotlib.projections import PolarAxes
from mpl_toolkits.axisartist.grid_finder import MaxNLocator
import matplotlib.patches as patches

# define how your plots look:

def setup_axes(fig, rect, theta, radius):

    # PolarAxes.PolarTransform takes radian. However, we want our coordinate
    # system in degree
    tr = Affine2D().scale(np.pi/180., 1.) + NorthPolarAxes.NorthPolarTransform()

    # Find grid values appropriate for the coordinate (degree).
    # The argument is an approximate number of grids.
    grid_locator1 = angle_helper.LocatorD(2)

    # And also use an appropriate formatter:
    tick_formatter1 = angle_helper.FormatterDMS() #formatter#

    # set up number of ticks for the r-axis
    grid_locator2 = MaxNLocator(4)

    # the extremes are passed to the function
    grid_helper = floating_axes.GridHelperCurveLinear(tr,
                                extremes=(theta[0], theta[1], radius[0], radius[1]),
                                grid_locator1=grid_locator1,
                                grid_locator2=grid_locator2,
                                tick_formatter1= tick_formatter1,
                                tick_formatter2=None,
                                )

    ax1 = floating_axes.FloatingSubplot(fig, rect, grid_helper=grid_helper)
    fig.add_subplot(ax1)

    # adjust axis
    # the axis artist lets you call axis with
    # "bottom", "top", "left", "right"
    ax1.axis["left"].set_axis_direction("top")
    ax1.axis["right"].set_axis_direction("bottom")

    ax1.axis["bottom"].set_visible(False)
    ax1.axis["top"].set_axis_direction("left")
    ax1.axis["top"].toggle(ticklabels=True, label=True)
    ax1.axis["top"].major_ticklabels.set_axis_direction("right")
    ax1.axis["top"].major_ticklabels.set_fontsize(15)
    #ax1.axis["top"].major_ticklabels.set_rotation(90)
    ax1.axis["top"].label.set_axis_direction("right")
    ax1.axis["left"].label.set_text("R")
    #ax1.axis["top"].label.set_text(ur"$\theta$ [\u00b0]")
    ax1.axis["top"].label.set_rotation(90)
    
    
    # create a parasite axes
    aux_ax = ax1.get_aux_axes(tr)
  

    aux_ax.patch = ax1.patch # for aux_ax to have a clip path as in ax
    ax1.patch.zorder=0.9 # but this has a side effect that the patch is
                         # drawn twice, and possibly over some other
                         # artists. So, we decrease the zorder a bit to
                         # prevent this.

    return ax1, aux_ax

#
# call the plot setup to generate 3 subplots
#

fig = plt.figure(1, figsize=(4, 8))
fig.subplots_adjust(wspace=0.3, left=0.05, right=0.95)

ax1, aux_ax1 = setup_axes(fig, 111, theta=[0, 180], radius=[0, 1])

ax1.text(1.00, 1.00, ur"$\theta$ [\u00b0]",
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax1.transAxes)

#
# generate the data to plot
#
theta = np.linspace(0,90) # in degrees
radius = np.cos(6.*theta * np.pi/180.0)**2.0

# 
# populate the three subplots with the data
#
aux_ax1.plot(theta, radius, 'r')
aux_ax1.tick_params(axis='both', which='major', labelsize=35)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.projections import PolarAxes, register_projection
from matplotlib.transforms import Affine2D, Bbox, IdentityTransform

class NorthPolarAxes(PolarAxes):
    '''
    A variant of PolarAxes where theta starts pointing north and goes
    clockwise.
    '''
    name = 'northpolar'

    class NorthPolarTransform(PolarAxes.PolarTransform):
        def transform(self, tr):
            xy   = np.zeros(tr.shape, np.float_)
            t    = tr[:, 0:1]
            r    = tr[:, 1:2]
            x    = xy[:, 0:1]
            y    = xy[:, 1:2]
            x[:] = r * np.sin(t)
            y[:] = r * np.cos(t)
            return xy

        transform_non_affine = transform

        def inverted(self):
            return NorthPolarAxes.InvertedNorthPolarTransform()

    class InvertedNorthPolarTransform(PolarAxes.InvertedPolarTransform):
        def transform(self, xy):
            x = xy[:, 0:1]
            y = xy[:, 1:]
            r = np.sqrt(x*x + y*y)
            theta = np.arctan2(y, x)
            return np.concatenate((theta, r), 1)

        def inverted(self):
            return NorthPolarAxes.NorthPolarTransform()

    def _set_lim_and_transforms(self):
        PolarAxes._set_lim_and_transforms(self)
        self.transProjection = self.NorthPolarTransform()
        self.transData = (
            self.transScale + 
            self.transProjection + 
            (self.transProjectionAffine + self.transAxes))
        self._xaxis_transform = (
            self.transProjection +
            self.PolarAffine(IdentityTransform(), Bbox.unit()) +
            self.transAxes)
        self._xaxis_text1_transform = (
            self._theta_label1_position +
            self._xaxis_transform)
        self._yaxis_transform = (
            Affine2D().scale(np.pi * 2.0, 1.0) +
            self.transData)
        self._yaxis_text1_transform = (
            Affine2D().scale(1.0 / 360.0, 1.0) +
            self._yaxis_transform) #self._r_label1_position"" 

register_projection(NorthPolarAxes)

angle = np.arange(0, 360, 10, dtype=float) * np.pi / 180.0
arbitrary_data = (np.abs(np.sin(angle)) + 0.1 * 
    (np.random.random_sample(size=angle.shape) - 0.5))

plt.clf()
plt.subplot(1, 1, 1, projection='northpolar')
plt.plot(angle, arbitrary_data)
plt.show()

# %%
import numpy as np
def func(b0,bt):
    mp=1.67262158E-27
    c=3.0E8
    k0=(np.sqrt(1/(1-b0**2))-1)*mp*c*c
    kt=(np.sqrt(1/(1-bt**2))-1)*mp*c*c
    t1=np.log((k0/kt)*((kt+2*mp*c*c)/(k0+2*mp*c*c)))
    t2=2*np.log((b0/bt)*((1+np.sqrt(1-bt*bt))/(1+np.sqrt(1-b0*b0))))
    return t1,t2,t1-t2

# %%
func(0.8,0.7)
# Out:
# (0.40488183794006138, 0.40488183794006116, 2.2204460492503131e-16)

# %%
def func2(b0,bt):
    mp=1.67262158E-27
    c=3.0E8
    k0=(np.sqrt(1/(1-b0**2))-1)*mp*c*c
    kt=(np.sqrt(1/(1-bt**2))-1)*mp*c*c
    t1=np.log((k0/kt)*((kt+2*mp*c*c)/(k0+2*mp*c*c)))
    def integral(bPar,eps,kPerp,kPar):

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d, Axes3D
# %matplotlib inline

# %%
fig=plt.figure()

# %%
ax=Axes3D(fig)
ax.set_xlim(-1.5, 1.5)#(-1e9,2e9)
ax.set_ylim(-1.5, 1.5)#(-1e9,2e9)
ax.set_zlim(-1.5, 1.5)#(-1e9,2e9)
# Out:
# (-1.5, 1.5)

# %%
X,Y,Z=np.meshgrid(np.linspace(-1,1,5),np.linspace(-1,1,5),np.linspace(-1,1,5))

# %%
m=1.0E21
c1=1.0E-7

# %%
U=(3*c1*m*Z*X)/((X**2+Y**2+Z**2)**(5/2))
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: invalid value encountered in divide
#   if __name__ == '__main__':

# %%
V=(3*c1*m*Z*Y)/((X**2+Y**2+Z**2)**(5/2))
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: invalid value encountered in divide
#   if __name__ == '__main__':

# %%
W=(3*c1*m*Z*Z)/((X**2+Y**2+Z**2)**(5/2)) - (c1*m)/((X**2+Y**2+Z**2)**(5/2))
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: invalid value encountered in divide
#   if __name__ == '__main__':
# C:\Python27\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: divide by zero encountered in divide
#   if __name__ == '__main__':

# %%
ax.quiver(X,Y,Z,U,V,W,length=0.1)
plt.show()

# %%
fig

# %%
X,Z=np.meshgrid(np.linspace(-1.0E3,1.0E3,1000),np.linspace(-1.0E3,1.0E3,1000))

# %%
U=(3*c1*m*Z*X)/((X**2+Z**2)**(5/2))
W=(3*c1*m*Z*Z)/((X**2+Z**2)**(5/2)) - (c1*m)/((X**2+Z**2)**(5/2))

# %%
fig1, ax1=plt.subplots()

# %%
strm = ax1.streamplot(X, Z, U, W, color=((U**2+W**2)**(1/2)), linewidth=2, cmap=plt.cm.autumn)
fig1.colorbar(strm.lines)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0BF13198>

# %%
fig1

# %%
ax1.quiver(X,Z,U,W)

# %%
fig1
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Python27\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     224
#     225     if 'png' in formats:
# --> 226         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     227     if 'retina' in formats or 'png2x' in formats:
#     228         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python27\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
# ...

# %%
theta=np.linspace(0.01,np.pi,100)
for i in range(100):
    r0=0.5*float(i)
    X1,Z1=np.meshgrid(r0*np.sin(theta)*np.sin(theta)*np.cos(theta),r0*np.sin(theta)*np.sin(theta)*np.sin(theta))
    X2,Z2=np.meshgrid(-r0*np.sin(theta)*np.sin(theta)*np.cos(theta),r0*np.sin(theta)*np.sin(theta)*np.sin(theta))
    U1=(3*c1*m*Z1*X1)/((X1**2+Z1**2)**(5/2))
    W1=(3*c1*m*Z1*Z1)/((X1**2+Z1**2)**(5/2)) - (c1*m)/((X1**2+Z1**2)**(5/2))
    U2=(3*c1*m*Z2*X2)/((X2**2+Z2**2)**(5/2))
    W2=(3*c1*m*Z2*Z2)/((X2**2+Z2**2)**(5/2)) - (c1*m)/((X2**2+Z2**2)**(5/2))
    strm = ax1.streamplot(X1, Z1, U1, W1, color='k', linewidth=2)
    strm = ax1.streamplot(X2, Z2, U2, W2, color='k', linewidth=2)
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:6: RuntimeWarning: invalid value encountered in divide
# C:\Python27\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: invalid value encountered in divide
# C:\Python27\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: divide by zero encountered in divide
# C:\Python27\lib\site-packages\ipykernel\__main__.py:8: RuntimeWarning: invalid value encountered in divide
# C:\Python27\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: invalid value encountered in divide
# C:\Python27\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: divide by zero encountered in divide
# C:\Python27\lib\site-packages\matplotlib\streamplot.py:223: RuntimeWarning: divide by zero encountered in double_scalars
#   self.x_data2grid = grid.nx / grid.width
# C:\Python27\lib\site-packages\matplotlib\streamplot.py:224: RuntimeWarning: divide by zero encountered in double_scalars
#   self.y_data2grid = grid.ny / grid.height
# ...

# %%
fig1
